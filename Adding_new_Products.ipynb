# %% [markdown]
# # Read the Inventory

# %%
import json
fd=open("record.json","r")
r=fd.read()
fd.close()
record=json.loads(r)

# %%
record
# Out:
# {'12301': {'Brand_name': 'RAYMOND',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12302': {'Brand_name': 'REEBOK',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12308': {'Brand_name': 'SPYKAR',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12309': {'Brand_name': 'LEVIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12310': {'Brand_name': 'PUMA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12311': {'Brand_name': 'ADIDAS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12312': {'Brand_name': 'NIKE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12313': {'Brand_name': 'Peter England',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 's'},
#  '12314': {'Brand_name': 'zodiac',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12315': {'Brand_name': 'U.S.POLO ASSN.',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12316': {'Brand_name': 'METRONAUT',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12317': {'Brand_name': 'JACK&JONES',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12318': {'Brand_name': 'JASKART',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12319': {'Brand_name': 'ALLEN SOLLY',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12320': {'Brand_name': 'AEROPOSTALE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12321': {'Brand_name': 'HRX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12322': {'Brand_name': 'PROVOGUE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12323': {'Brand_name': 'PEPE JEANS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12324': {'  quantity': 100,
#   'Brand_name': 'PARAX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'size': 'L'},
#  '12325': {'Brand_name': 'KIANI',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12353': {'Brand_name': 'ROADSTER',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12354': {'Brand_name': 'LEANA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12357': {'Brand_name': 'BILLION',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12359': {'Brand_name': 'LASMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12360': {'Brand_name': 'SUPREMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12361': {'Brand_name': 'LEE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12362': {'Brand_name': 'GLITO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12363': {'Brand_name': 'CANIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12365': {'Brand_name': 'GNS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12398': {'Brand_name': 'WRATH',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'}}

# %% [markdown]
# # Add New-Brand to my inventory

# %%
s=int(input('how many brand name you add to this inventory: '))
for i in range(s): 
    print('Brand',i+1)
    prod_id=input('enter product id of new brand tshirt: ')
    Brand_Name=input('enter the name of that latest_new brand name: ')
    price=int(input('enter the price of that tshirt: '))
    Quantity=int(input('enter the quantity of that tshirt: '))             
    Discount=int(input('enter the discount of that tshirt(in %): '))
    print()
    def menu():
        print('1-for choosing what is the sleeve type of that t-shirt: ')
        print('2-for choosing what is the size of that t-shirt: ')
        print('3-for choosing what is the neck-type of that t-shirt: ')
        print()
        return input('please select an option in a countinious manner')
    
    run=menu()
    while True:
        if( run =='1'):
            print('1--for  Full sleeve')
            print('2-- Half sleeve')
            print('3-- Short Sleeve')
            print('4-- Sleeveless')
            print()
            x=input('chose an option: ')
            if (x=='1'):
                Slv_type='Full sleeve'
                print(Slv_type)
            elif(x=='2'):
                Slv_type='Half sleeve'
                print(Slv_type)
            elif (x=='3'):
                Slv_type='Short Sleeve'
                print(Slv_type)
            elif (x=='4'):
                Slv_type='Sleeveless'
                print(Slv_type)
            
            break
        
    print()
    run=menu()
    while True:
        if( run =='2'):
            print('1-- Large')
            print('2-- Small')
        
            print()
            x=input('chose an option: ')
            if (x=='1'):
                Size='L'
                print(Size)
            elif(x=='2'):
                Size='S'
                print(Size)
        
            break
    print()
    run=menu()
    while True:
        if( run =='3'):
            print('1-- V Neck')
            print('2-- Round Neck')
        
            print()
            x=input('chose an option: ')
            if (x=='1'):
                Neck_typ='V Neck'
                print(Neck_typ)
            elif(x=='2'):
                Neck_typ='Round Neck'
                print(Neck_typ)
        
            break
            
    record[prod_id]={'Brand_name':  Brand_Name,                       'price':price,  'quantity':Quantity, 'discount in %:':Discount, 'Sleeve_Type':Slv_type, 'size':Size, 'Neck_Type':Neck_typ}
    
    js=json.dumps(record)
    
    fd=open("record.json","w")
    fd.write(js)
    fd.close()
# Out:
# how many brand name you add to this inventory: 2
# Brand 1
# enter product id of new brand tshirt: 12329
# enter the name of that latest_new brand name: Weft
# enter the price of that tshirt: 500
# enter the quantity of that tshirt: 100
# enter the discount of that tshirt(in %): 10
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner1
# 1--for  Full sleeve
# 2-- Half sleeve
# 3-- Short Sleeve
# 4-- Sleeveless
#
# chose an option: 4
# Sleeveless
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner2
# 1-- Large
# 2-- Small
#
# chose an option: 2
# S
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner3
# 1-- V Neck
# 2-- Round Neck
#
# chose an option: 1
# V Neck
# Brand 2
# enter product id of new brand tshirt: 12332
# enter the name of that latest_new brand name: Race
# enter the price of that tshirt: 500
# enter the quantity of that tshirt: 100
# enter the discount of that tshirt(in %): 10
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner1
# 1--for  Full sleeve
# 2-- Half sleeve
# 3-- Short Sleeve
# 4-- Sleeveless
#
# chose an option: 2
# Half sleeve
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner2
# 1-- Large
# 2-- Small
#
# chose an option: 1
# L
#
# 1-for choosing what is the sleeve type of that t-shirt:
# 2-for choosing what is the size of that t-shirt:
# 3-for choosing what is the neck-type of that t-shirt:
#
# please select an option in a countinious manner3
# 1-- V Neck
# 2-- Round Neck
#
# chose an option: 2
# Round Neck

# %%
record
# Out:
# {'12301': {'Brand_name': 'RAYMOND',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12302': {'Brand_name': 'REEBOK',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12308': {'Brand_name': 'SPYKAR',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12309': {'Brand_name': 'LEVIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12310': {'Brand_name': 'PUMA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12311': {'Brand_name': 'ADIDAS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12312': {'Brand_name': 'NIKE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12313': {'Brand_name': 'Peter England',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 's'},
#  '12314': {'Brand_name': 'zodiac',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12315': {'Brand_name': 'U.S.POLO ASSN.',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12316': {'Brand_name': 'METRONAUT',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12317': {'Brand_name': 'JACK&JONES',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12318': {'Brand_name': 'JASKART',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12319': {'Brand_name': 'ALLEN SOLLY',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12320': {'Brand_name': 'AEROPOSTALE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12321': {'Brand_name': 'HRX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12322': {'Brand_name': 'PROVOGUE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12323': {'Brand_name': 'PEPE JEANS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12324': {'  quantity': 100,
#   'Brand_name': 'PARAX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'size': 'L'},
#  '12325': {'Brand_name': 'KIANI',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12329': {'Brand_name': 'Weft',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Sleeveless',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'S'},
#  '12332': {'Brand_name': 'Race',
#   'Neck_Type': 'Round Neck',
#   'Sleeve_Type': 'Half sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12353': {'Brand_name': 'ROADSTER',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12354': {'Brand_name': 'LEANA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12357': {'Brand_name': 'BILLION',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12359': {'Brand_name': 'LASMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12360': {'Brand_name': 'SUPREMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12361': {'Brand_name': 'LEE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12362': {'Brand_name': 'GLITO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12363': {'Brand_name': 'CANIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12365': {'Brand_name': 'GNS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12398': {'Brand_name': 'WRATH',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'}}

# %% [markdown]
# # After adding something in present inventory,updatation of that inventory

# %%
w=input('Enter product id of brand tshirt present in store for updatation : ')
x=input('Enter the name of that brand name: ')
y=int(input('Enter the increased price for this brand-tshirt: '))
z=int(input('Enter the increased quantity for this brand-tshirt: '))             
m=int(input('Enter the increased(with no sign)  & decrease(in -ve) discount for this brand-tshirt(in %): '))
record[w]['price']=record[w]['price']+y 
record[w]['quantity']=str(int(record[w]['quantity'])+z)
record[w]['discount in %:']=str(int(record[w]['discount in %:'])+m)
print('**********************************************************************')
print('after updatation of inventory by adding some items for other benifits: ')
print('**********************************************************************')
record
# Out:
# Enter product id of brand tshirt present in store for updatation : 12362
# Enter the name of that brand name: GLITO
# Enter the increased price for this brand-tshirt: 100
# Enter the increased quantity for this brand-tshirt: 100
# Enter the increased(with no sign)  & decrease(in -ve) discount for this brand-tshirt(in %): 10
# **********************************************************************
# after updatation of inventory by adding some items for other benifits:
# **********************************************************************
# {'12301': {'Brand_name': 'RAYMOND',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12302': {'Brand_name': 'REEBOK',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12308': {'Brand_name': 'SPYKAR',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12309': {'Brand_name': 'LEVIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12310': {'Brand_name': 'PUMA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12311': {'Brand_name': 'ADIDAS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12312': {'Brand_name': 'NIKE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12313': {'Brand_name': 'Peter England',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 's'},
#  '12314': {'Brand_name': 'zodiac',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12315': {'Brand_name': 'U.S.POLO ASSN.',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12316': {'Brand_name': 'METRONAUT',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12317': {'Brand_name': 'JACK&JONES',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12318': {'Brand_name': 'JASKART',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12319': {'Brand_name': 'ALLEN SOLLY',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12320': {'Brand_name': 'AEROPOSTALE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12321': {'Brand_name': 'HRX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12322': {'Brand_name': 'PROVOGUE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12323': {'Brand_name': 'PEPE JEANS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12324': {'  quantity': 100,
#   'Brand_name': 'PARAX',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'size': 'L'},
#  '12325': {'Brand_name': 'KIANI',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12329': {'Brand_name': 'Weft',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Sleeveless',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'S'},
#  '12332': {'Brand_name': 'Race',
#   'Neck_Type': 'Round Neck',
#   'Sleeve_Type': 'Half sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12353': {'Brand_name': 'ROADSTER',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12354': {'Brand_name': 'LEANA',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12357': {'Brand_name': 'BILLION',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12359': {'Brand_name': 'LASMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12360': {'Brand_name': 'SUPREMO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12361': {'Brand_name': 'LEE',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12362': {'Brand_name': 'GLITO',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': '20',
#   'price': 600,
#   'quantity': '200',
#   'size': 'L'},
#  '12363': {'Brand_name': 'CANIS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12365': {'Brand_name': 'GNS',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'},
#  '12398': {'Brand_name': 'WRATH',
#   'Neck_Type': 'V Neck',
#   'Sleeve_Type': 'Full Sleeve',
#   'discount in %:': 10,
#   'price': 500,
#   'quantity': 100,
#   'size': 'L'}}
